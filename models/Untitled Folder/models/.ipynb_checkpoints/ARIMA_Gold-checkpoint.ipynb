# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas_datareader import data as pdr
import yfinance as yf
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from math import sqrt
import itertools
import warnings

# Function to encapsulate your ARIMA stock price prediction
def predict_stock_prices(symbol, start_date="2010-01-01", end_date=None):
    # Ignore warnings
    warnings.filterwarnings("ignore")

    # Set up Yahoo Finance data source
    yf.pdr_override()

    # Get historical stock data
    stock_data = pdr.get_data_yahoo(symbol, start=start_date, end=end_date)

    # Extract closing prices
    closing_prices = stock_data["Close"]

    # Divide data into training and testing sets
    train_data = closing_prices[:int(len(closing_prices) * 0.8)]
    test_data = closing_prices[int(len(closing_prices) * 0.8):]

    # Determine optimal ARIMA parameters with grid search
    # (0,5) for all gives RMSE of 112
    # (0,10) gives RMSE of 162. This indicates that the best combination is around 5
    p_values = range(0, 5)
    d_values = range(0, 1)
    q_values = range(0, 5)
    pdq_combinations = list(itertools.product(p_values, d_values, q_values))
    best_aic = float("inf")
    best_order = None
    best_model = None

    for order in pdq_combinations:
        try:
            model = ARIMA(train_data, order=order)
            model_fit = model.fit()
            if model_fit.aic < best_aic:
                best_aic = model_fit.aic
                best_order = order
                best_model = model_fit
        except Exception as e:
            continue

    # Forecast stock prices using optimal ARIMA model
    predictions = best_model.forecast(steps=len(test_data))

    # Compute root mean squared error (RMSE)
    rmse = sqrt(mean_squared_error(test_data, predictions))

    # Plotting the results (you can also choose to return values instead)
    plt.figure(figsize=(12, 6))
    plt.plot(train_data, label="Training data")
    plt.plot(test_data, label="Actual closing prices")
    plt.plot(test_data.index, predictions, label="Predicted closing prices")
    plt.xlabel("Date")
    plt.ylabel("Closing Price")
    plt.title(f"{symbol} Stock Closing Price Prediction using ARIMA")
    plt.legend()
    plt.show()

    # Optionally, return the rmse, predictions, and/or other relevant information
    return rmse, best_order

# Example usage
symbol = "GC=F"
rmse, best_order = predict_stock_prices(symbol)
print(f"RMSE: {rmse}, Best ARIMA Order: {best_order}")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# RMSE: 162.99010969340992, Best ARIMA Order: (5, 0, 5)

# %%
# Assuming 'predict_stock_prices' is already defined and executed to get 'best_model' and 'last_known_date'.

def predict_next_day_price(best_model, last_known_price_date):
    # Forecast the next day's price
    next_day_forecast = best_model.get_forecast(steps=1)
    next_day_price = next_day_forecast.predicted_mean.iloc[0]
    return next_day_price

# Example usage to predict the next day's price for gold
symbol = "GC=F"
rmse, best_order, best_model, last_known_date = predict_stock_prices(symbol)

# Now predict the next day's closing price
next_day_price = predict_next_day_price(best_model, last_known_date)

# This will print the exact predicted closing price for the next day
print(next_day_price)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 11
#       9 # Example usage to predict the next day's price for gold
#      10 symbol = "GC=F"
# ---> 11 rmse, best_order, best_model, last_known_date = predict_stock_prices(symbol)
#      13 # Now predict the next day's closing price
#      14 next_day_price = predict_next_day_price(best_model, last_known_date)
#
# ValueError: not enough values to unpack (expected 4, got 2)
