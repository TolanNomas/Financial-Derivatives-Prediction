# %% [markdown]
# **Initial Data Retrival and Cleaning**

# %%
import yfinance as yf
import pandas as pd

# Get data on this ticker (gold to start with)
tickerDF = yf.Ticker('GC=F')

# Get the historical prices for this ticker
tickerDF = tickerDF.history(period='max')

#displaying gold index
tickerDF.index
# Out:
# DatetimeIndex(['2000-08-30 00:00:00-04:00', '2000-08-31 00:00:00-04:00',
#                '2000-09-01 00:00:00-04:00', '2000-09-05 00:00:00-04:00',
#                '2000-09-06 00:00:00-04:00', '2000-09-07 00:00:00-04:00',
#                '2000-09-08 00:00:00-04:00', '2000-09-11 00:00:00-04:00',
#                '2000-09-12 00:00:00-04:00', '2000-09-13 00:00:00-04:00',
#                ...
#                '2024-03-11 00:00:00-04:00', '2024-03-12 00:00:00-04:00',
#                '2024-03-13 00:00:00-04:00', '2024-03-14 00:00:00-04:00',
#                '2024-03-15 00:00:00-04:00', '2024-03-18 00:00:00-04:00',
#                '2024-03-19 00:00:00-04:00', '2024-03-20 00:00:00-04:00',
#                '2024-03-21 00:00:00-04:00', '2024-03-22 00:00:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=5913, freq=None)

# %%
# plotting gold index
tickerDF.plot.line(y="Close", use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %%
# removing unneeded columns
del tickerDF["Dividends"]
del tickerDF["Stock Splits"]

# %%
# adds column that will be tomorrow's price 
#(the particular stocks price the following day)
tickerDF["Tomorrow"] = tickerDF["Close"].shift(-1)

# %%
#sets a target that indicates is what we will aim to predict. 
#Returns an int for ML use
#returns 1 when price goes up
#returns 0 when price goes down
tickerDF["Target"] = (tickerDF["Tomorrow"] > tickerDF["Close"]).astype(int)

# %%
#removing all data that comes before 1990
tickerDF = tickerDF.loc["1990-01-01":].copy()

# %% [markdown]
# **Initial ML Model**

# %%
from sklearn.ensemble import RandomForestClassifier

#random forest works by training a set of indiv decision trees
##with randomised parameters
###it then averages the results to resist overfitting and
####can pick up non-linear relationships (most of this data)

#100 initial trees to test
##100 min samples to protect against overfitting
###(higher = less overfitting but less model acuracy)
model = RandomForestClassifier(n_estimators=100, min_samples_split=100, random_state=1)

#splitting data into train and test set
##time-series data can't use cross-validation to split data. Results in leakage
train = tickerDF.iloc[:-100]
test= tickerDF.iloc[-100:]

#simple baseline model for now
#careful not to use tomorrow column
predictors = ["Close", "Volume", "Open", "High", "Low"]

#train model using predictor columns in order to predict target
model.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
#meausure model accuracy
# what percentage of time did the model claim prices would go up and actually did
from sklearn.metrics import precision_score

preds = model.predict(test[predictors])

#changing to panda series
preds = pd.Series(preds, index=test.index)

# %%
#calculating precision_score using actual Target and predicted target
precision_score(test["Target"], preds)
# Out:
# 0.8333333333333334

# %%
#plot predictions 
combined = pd.concat([test["Target"], preds], axis=1)
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Backtesting System

# %%
# function which brings all of the above together
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
#each trading year has roughly 250 trading days
#trains model for year before moving on
#trains for 10 years then predicts for 11th year

def backtest(data, model, predictors, start=2500, step=250):
    all_predictions = []

    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    
    return pd.concat(all_predictions)

# %%
predictions = backtest(tickerDF, model, predictors)

# %%
# 1 is times price went up as predicted
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 1    2170
# 0    1243
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5087557603686635

# %%
#market went up ~51% of the time as predicted

#benchmark of days market actually went up
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# Target
# 1    0.516554
# 0    0.483446
# Name: count, dtype: float64

# %%
#algorithm performed worse than if picking randomly

# %%
# rolling averages
# mean close price in last 2 days, trading week, 3 months , last year , last 4 years
# find ratio between today's closing price and the closing price in these periods
horizons = [2,5,60,250,1000]

new_predictors = []

#loops through each average 
for horizon in horizons:
    rolling_averages = tickerDF.rolling(horizon).mean()
    
    ratio_column = f"Close_Ratio_{horizon}"
    tickerDF[ratio_column] = tickerDF["Close"] / rolling_averages["Close"]
    
    # number of days stock price went up
    trend_column = f"Trend_{horizon}"
    tickerDF[trend_column] = tickerDF.shift(1).rolling(horizon).sum()["Target"]
    
    new_predictors += [ratio_column, trend_column]

tickerDF = tickerDF.dropna(subset=tickerDF.columns[tickerDF.columns != "Tomorrow"])

# %%
model = RandomForestClassifier(n_estimators=200, min_samples_split=50, random_state=1)

# %%
#reduce total number of trading days
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict_proba(test[predictors])[:,1]
    preds[preds >=.6] = 1
    preds[preds <.6] = 0
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
predictions = backtest(tickerDF, model, new_predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0.0    2093
# 1.0     320
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.53125

# %%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# Target
# 1    0.514712
# 0    0.485288
# Name: count, dtype: float64

# %%
# Model preformed at 52.97% accuracy versus target of 51.36%
predictions
# Out:
#                            Target  Predictions
# Date
# 2014-08-20 00:00:00-04:00       0          0.0
# 2014-08-21 00:00:00-04:00       1          0.0
# 2014-08-22 00:00:00-04:00       0          0.0
# 2014-08-25 00:00:00-04:00       1          0.0
# 2014-08-26 00:00:00-04:00       0          0.0
# ...                           ...          ...
# 2024-03-18 00:00:00-04:00       0          0.0
# 2024-03-19 00:00:00-04:00       1          0.0
# 2024-03-20 00:00:00-04:00       1          0.0
# 2024-03-21 00:00:00-04:00       0          0.0
# 2024-03-22 00:00:00-04:00       0          0.0
#
# [2413 rows x 2 columns]

# %%
# Load the most recent data for gold
ticker = yf.Ticker('GC=F')
latest_data = ticker.history(period='max')

# Prepare the data in the same way as the training data
latest_row = tickerDF.iloc[-1:].copy()
latest_row.loc[:, 'Close'] = latest_data['Close'].iloc[-1]
latest_row.loc[:, 'Volume'] = latest_data['Volume'].iloc[-1]
latest_row.loc[:, 'Open'] = latest_data['Open'].iloc[-1]
latest_row.loc[:, 'High'] = latest_data['High'].iloc[-1]
latest_row.loc[:, 'Low'] = latest_data['Low'].iloc[-1]

# Update the rolling averages and trend features for the prediction
for horizon in [2,5,60,250,1000]:
    rolling_averages = tickerDF['Close'].rolling(window=horizon).mean()
    latest_row[f'Close_Ratio_{horizon}'] = latest_row['Close'] / rolling_averages.iloc[-1]
    
    # Calculate trend based on 'Target' column
    trend = (tickerDF['Close'].shift(-1) > tickerDF['Close']).astype(int)
    rolling_trend = trend.rolling(window=horizon).sum()
    latest_row[f'Trend_{horizon}'] = rolling_trend.iloc[-1]

# Ensure we only use the columns that the model was trained on
predictors = ["Close", "Volume", "Open", "High", "Low"]
new_predictors = [f"Close_Ratio_{h}" for h in [2,5,60,250,1000]] + [f"Trend_{h}" for h in [2,5,60,250,1000]]

# Make prediction using the latest row
# We assume 'model' is your trained RandomForestClassifier
prediction = model.predict(latest_row[predictors + new_predictors])

# Output prediction result
if prediction[0] == 1:
    print("The model predicts the price of gold will go UP tomorrow.")
else:
    print("The model predicts the price of gold will go DOWN tomorrow.")
# Out:
# The model predicts the price of gold will go DOWN tomorrow.
